# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# %%
raw_data = pd.read_csv("./knapsack_problem_1_14_bit_max_wt_90_sbc_op_steepest_node_counts.csv")

# %%
raw_data.head()
# Out:
#      id  count
# 0  5151      1
# 1  5143      1
# 2  5343      1
# 3  5215      1
# 4  5855      1

# %%
node_dist = Counter(node for node in raw_data['id'])

# %%
node_dist
# Out:
# Counter({5151: 46,
#          5143: 19,
#          5343: 789,
#          5215: 97,
#          5855: 1604,
#          11771: 65,
#          12283: 170,
#          11755: 8,
#          6750: 101,
#          6878: 173,
#          16094: 2727,
#          6746: 15,
#          15070: 613,
#          10606: 105,
#          10592: 7,
#          15342: 2201,
#          10596: 19,
#          10734: 188,
#          10598: 29,
#          14830: 763,
#          9071: 92,
#          9199: 376,
#          10223: 1961,
#          6839: 27,
#          15039: 639,
#          6837: 15,
#          6833: 9,
#          6847: 282,
#          14331: 73,
#          13307: 7,
#          11694: 46,
#          11684: 18,
#          11686: 24,
#          11758: 186,
#          12270: 385,
#          2734: 46,
#          10991: 3213,
#          2799: 791,
#          2798: 200,
#          7119: 3146,
#          6601: 6,
#          6607: 1581,
#          6605: 11,
#          9695: 1497,
#          9685: 14,
# ...
