# %%
library(tidyverse)
# Out:
# Loading tidyverse: ggplot2
# Loading tidyverse: tibble
# Loading tidyverse: tidyr
# Loading tidyverse: readr
# Loading tidyverse: purrr
# Loading tidyverse: dplyr
# Conflicts with tidy packages ---------------------------------------------------
# filter(): dplyr, stats
# lag():    dplyr, stats

# %% [markdown]
# # REDO counts. Seems the random seed was being used

# %%
raw_data_RAN_random_14_bit = read.csv("./RAN_Validation/knapsack_problem_1/14_bit/max_wt_90/knapsack_problem_1_14_bit_max_wt_90_sbc_op_random_node_counts_1_with_RAN_eigen_vals_and_fitnesses_and_peaks_1.csv")
counts_RAN_random_14_bit = raw_data_RAN_random_14_bit %>% 
  group_by(id) %>%
  summarise(count = sum(count), eigen_cent = mean(eigen_cent), fitness = mean(fitness), is_peak = first(is_peak))

# %%
ggplot(counts_RAN_random_14_bit) +
  aes(x=eigen_cent, y=count) +
  geom_point()
# Out:
# plot without title

# %%
counts_RAN_random_14_bit %>%  
#   filter(is_peak == "True") %>%
  ggplot() +
  aes(x=fitness, y=count) +
    geom_point()
# Out:
# plot without title

# %%
counts_RAN_random_14_bit %>%  
#   filter(is_peak == "True") %>%
  ggplot() +
  aes(x=fitness, y=eigen_cent) +
    geom_point()
# Out:
# plot without title

# %%
counts_RAN_random_14_bit %>%
  filter(count < 100) %>%
#   filter(is_peak == "True") %>%
  ggplot() +
  aes(x=fitness, y=count) +
    geom_point()
# Out:
# plot without title

# %%
counts_RAN_random_14_bit %>%
filter(count < 100) %>%
  ggplot() +
    aes(x=eigen_cent, y=count) +
    geom_point()
# Out:
# plot without title

# %%
counts_RAN_random_14_bit %>%
  filter(count < 100) %>%
  filter(is_peak == "False") %>%
  ggplot() +
    aes(x=eigen_cent, y=count) +
    geom_point()
# Out:
# plot without title

# %%
counts_RAN_random_14_bit %>%
  filter(fitness == 0)
# Out:
#     id    count eigen_cent fitness is_peak
# 1      0  1301  1.0000000  0       False
# 2    511   965  0.8619075  0       False
# 3   1023   908  0.7960514  0       False
# 4   1535   923  0.7815972  0       False
# 5   1791   883  0.7244498  0       False
# 6   2047   798  0.6972550  0       False
# 7   2303   971  0.8292697  0       False
# 8   2527  1024  0.8462646  0       False
# 9   2559   832  0.7536124  0       False
# 10  2815   798  0.6915076  0       False
# 11  3039   817  0.7199238  0       False
# 12  3055   822  0.7248547  0       False
# 13  3071   713  0.6099611  0       False
# 14  3295   971  0.8579113  0       False
# 15  3327   898  0.7553115  0       False
# 16  3455  1018  0.8552392  0       False
# 17  3551   989  0.8412783  0       False
# 18  3567   986  0.8010711  0       False
# 19  3582  1012  0.8471381  0       False
# 20  3583   863  0.7993183  0       False
# 21  3807   833  0.7182752  0       False
# 22  3839   689  0.6008635  0       False
# 23  3967   813  0.6992655  0       False
# 24  4063   779  0.6828434  0       False
# 25  4079   796  0.6843098  0       False
# 26  4094   758  0.6510310  0       False
# 27  4095   623  0.5819371  0       False
# 28  4351  1042  0.8664508  0       False
# 29  4607   866  0.7688031  0       False
# 30  4863   958  0.8046764  0       False
# ⋮   ⋮     ⋮     ⋮          ⋮       ⋮
# 200 15855 756   0.6923368  0       False
# 201 15863 756   0.7046133  0       False
# 202 15867 790   0.7046447  0       False
# 203 15869 769   0.7019986  0       False
# 204 15870 850   0.7493826  0       False
# 205 15871   5   0.6988215  0       False
# 206 15999 518   0.4791386  0       False
# 207 16063 609   0.5292629  0       False
# 208 16079 637   0.5337340  0       False
# 209 16095 542   0.4850778  0       False
# 210 16111 570   0.4976760  0       False
# 211 16119 655   0.5337740  0       False
# 212 16125 648   0.5390805  0       False
# 213 16126 589   0.5185011  0       False
# 214 16127 538   0.4912890  0       False
# 215 16223 475   0.4062611  0       False
# 216 16239 352   0.2920260  0       False
# 217 16255 290   0.3067433  0       False
# 218 16319 209   0.2091327  0       False
# 219 16335 531   0.4381817  0       False
# 220 16343 465   0.4036021  0       False
# 221 16350 487   0.4588866  0       False
# 222 16351 375   0.3911001  0       False
# 223 16366 426   0.3550903  0       False
# 224 16367 374   0.3418626  0       False
# 225 16375 298   0.2687962  0       False
# 226 16379 176   0.1739539  0       False
# 227 16381 233   0.2421806  0       False
# 228 16382 338   0.3368748  0       False
# 229 16383   8   0.3997311  0       False

# %%
counts_RAN_random_14_bit %>%
  filter(count < 100) %>%
  filter(is_peak == "False")
# Out:
#   id    count eigen_cent fitness is_peak
# 1  7679 12    0.7752553  0       False
# 2  8191  8    0.6247808  0       False
# 3 15359  7    0.5761510  0       False
# 4 15871  5    0.6988215  0       False
# 5 16383  8    0.3997311  0       False

# %%
counts_RAN_random_14_bit %>%
  filter(count < 100) %>%
  filter(is_peak == "True")
# Out:
#     id    count eigen_cent fitness is_peak
# 1   1279   2    0.8895409  426     True
# 2   2015   5    0.8085292  419     True
# 3   2543   7    0.8915612  432     True
# 4   2783   1    0.8441954  427     True
# 5   2943   6    0.8217786  417     True
# 6   3070  11    0.8142799  425     True
# 7   3823   4    0.8139128  432     True
# 8   3838   6    0.8097198  422     True
# 9   4087   5    0.7964645  417     True
# 10  4093   7    0.7953674  411     True
# 11  4575   5    0.8830544  434     True
# 12  5103   5    0.8354583  430     True
# 13  5630   4    0.8859552  429     True
# 14  5855  11    0.8100991  434     True
# 15  6015   3    0.7835748  424     True
# 16  6398   5    0.8910235  437     True
# 17  6653  10    0.8853521  426     True
# 18  6783  11    0.8413724  432     True
# 19  7103   4    0.8193377  437     True
# 20  7119   4    0.8098481  440     True
# 21  7134   8    0.8258300  430     True
# 22  7163   4    0.8289462  422     True
# 23  7415   9    0.8863052  429     True
# 24  7519   8    0.8812901  431     True
# 25  7871   9    0.8072363  434     True
# 26  7887   5    0.8005454  437     True
# 27  7933   4    0.8057136  426     True
# 28  8047   6    0.7619831  427     True
# 29  8151  11    0.7929863  422     True
# 30  8174   5    0.7811276  435     True
# ⋮   ⋮     ⋮     ⋮          ⋮       ⋮
# 87  15967  7    0.7401823  439     True
# 88  15983  6    0.7266500  432     True
# 89  16087 13    0.7526875  427     True
# 90  16094  5    0.7528078  447     True
# 91  16110  6    0.7420652  440     True
# 92  16123  5    0.7313831  439     True
# 93  16191 11    0.7103742  419     True
# 94  16207  9    0.7059545  422     True
# 95  16247  6    0.7151311  417     True
# 96  16251 12    0.7062355  404     True
# 97  16253  3    0.7135570  411     True
# 98  16254  4    0.7206099  437     True
# 99  16287  8    0.7194919  444     True
# 100 16303  6    0.7131081  437     True
# 101 16311 11    0.7126426  407     True
# 102 16315  6    0.7037470  394     True
# 103 16317  6    0.7110685  401     True
# 104 16318  2    0.7181214  427     True
# 105 16334 11    0.7251871  430     True
# 106 16347  3    0.7153532  429     True
# 107 16349  2    0.7226747  436     True
# 108 16359  4    0.7178650  435     True
# 109 16363  4    0.7089694  422     True
# 110 16365  7    0.7162909  429     True
# 111 16371  5    0.7085039  392     True
# 112 16373  7    0.7158254  399     True
# 113 16374  5    0.7228783  425     True
# 114 16377  9    0.7069298  386     True
# 115 16378  4    0.7139827  412     True
# 116 16380  9    0.7213042  419     True

# %%
counts_RAN_random_14_bit %>%
  summarise(count = sum(count))
# Out:
#   count
# 1 18734361

# %%
counts_RAN_random_14_bit %>%
  summarise(max_fit = max(fitness))
# Out:
#   max_fit
# 1 454

# %%
counts_RAN_random_14_bit %>%
  filter(eigen_cent < 0.3)
# Out:
#   id    count eigen_cent fitness is_peak
# 1 16239 352   0.2920260  0       False
# 2 16319 209   0.2091327  0       False
# 3 16375 298   0.2687962  0       False
# 4 16379 176   0.1739539  0       False
# 5 16381 233   0.2421806  0       False
